# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\user1\Desktop\Baes Rock Papers Scissors Amari Lawal\data\overall_results.csv")
df
# Out:
#     Unnamed: 0  Q CPU Wins  Q CPU Loses  Draws  Total Games Played
# 0            0       16749        16591  16660               50000
# 1            0       16703        16615  16682               50000
# 2            0       16703        16615  16682               50000
# 3            0       16703        16615  16682               50000
# 4            0       16703        16615  16682               50000
# 5            0       16465        16669  16866               50000
# 6            0       16583        16665  16752               50000
# 7            0       16504        16641  16855               50000
# 8            0       16641        16810  16549               50000
# 9            0           0            0      1                   1
# 10           0       16581        16754  16665               50000
# 11           0       16666        16731  16603               50000
# 12           0       16823        16645  16532               50000
# ...

# %%
df.iloc[:,1:3]
# Out:
#     Q CPU Wins  Q CPU Loses
# 0        16749        16591
# 1        16703        16615
# 2        16703        16615
# 3        16703        16615
# 4        16703        16615
# 5        16465        16669
# 6        16583        16665
# 7        16504        16641
# 8        16641        16810
# 9            0            0
# 10       16581        16754
# 11       16666        16731
# 12       16823        16645
# 13       16840        16610
# 14       16771        16777
# 15       16721        16617
# 16       16505        16770
# 17       16575        16724
# 18       16487        16670
# 19       16841        16599
# 20       16828        16594
# 21       16715        16551
# 22       16753        16575
# 23       16785        16677
# 24       16727        16585
# 25       16563        16709
# 26       16613        16738

# %%
m = list(pd.DataFrame(list(df.columns),columns=["Options"])["Options"]) #
m.remove('Unnamed: 0')
m
# Out:
# ['Q CPU Wins', 'Q CPU Loses', 'Draws', 'Total Games Played']

# %%
plt.bar(m[0],df['Q CPU Wins'])
plt.show()
